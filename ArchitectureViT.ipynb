# %% [markdown]
# ## Vision Transformer

# %%
!pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.21-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from kagglehub) (2.32.4)
# Collecting tqdm (from kagglehub)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: protobuf in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/honiluna/Library/Caches/pypoetry/virtualenvs/image-classification-Jd2OWZNc-py3.10/lib/python3.10/site-packages (from requests->kagglehub) (2025.6.15)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.21-py3-none-any.whl (212 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [kagglehub]/3 [kagglesdk]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.21 tqdm-4.67.3
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("wwymak/architecture-dataset")

print("Path to dataset files:", path)
# Out:
# Resuming download from 76546048 bytes (1459887034 bytes left)...
# Resuming download to /Users/honiluna/.cache/kagglehub/datasets/wwymak/architecture-dataset/1.archive (76546048/1536433082) bytes left.
# 100%|██████████| 1.43G/1.43G [01:39<00:00, 14.7MB/s]
# Extracting files...
# Path to dataset files: /Users/honiluna/.cache/kagglehub/datasets/wwymak/architecture-dataset/versions/1
